# %%
import sys
import os

import pandas as pd 
import numpy as np

import mlflow
import mlflow.sklearn
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import (
    LinearRegression, Ridge, Lasso, ElasticNet, BayesianRidge, HuberRegressor
)
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures
from datetime import datetime
import numpy as np


project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))
if project_root not in sys.path:
    sys.path.append(project_root)

from data_collection.data_collector import DataCollector

# %%
data_col = DataCollector()
data = data_col.get_historical_data(symbol="EURUSD")
data.head()
# Out:
#               Open   Close    High     Low  Volume
# Date
# 1971-01-04  0.5369  0.5369  0.5369  0.5369       1
# 1971-01-05  0.5366  0.5366  0.5366  0.5366       1
# 1971-01-06  0.5365  0.5365  0.5365  0.5365       1
# 1971-01-07  0.5368  0.5368  0.5368  0.5368       1
# 1971-01-08  0.5371  0.5371  0.5371  0.5371       1

# %%
def tune_and_log_models(X, y, models=None, param_grids=None, cv=5):
    """
    Проходит по списку моделей, подбирает гиперпараметры и логирует лучшие модели в MLflow с RMSE.

    Параметры:
    ----------
    X : array-like
        Массив признаков (матрица X).
    y : array-like
        Целевая переменная (вектор y).
    models : dict или None
        Словарь моделей, где ключи - названия моделей, а значения - сами модели.
    param_grids : dict или None
        Словарь параметров, где ключи - названия моделей, а значения - сетки гиперпараметров.
    cv : int
        Количество фолдов для кросс-валидации.

    Возвращает:
    -----------
    results : dict
        Словарь с лучшими моделями, их параметрами и оценками.
    """

    if models is None:
        models = {
            'linear': LinearRegression(),
            'ridge': Ridge(),
            'lasso': Lasso(),
            'elasticnet': ElasticNet(),
            'svr': SVR(),
            'decision_tree': DecisionTreeRegressor(),
            'random_forest': RandomForestRegressor(),
            'gbr': GradientBoostingRegressor(),
            'knn': KNeighborsRegressor(),
            'polynomial': Pipeline([
                ('poly', PolynomialFeatures()),
                ('linear', LinearRegression())
            ]),
            'bayesian': BayesianRidge(),
            'huber': HuberRegressor()
        }

    if param_grids is None:
        param_grids = {
            'ridge': {'alpha': [0.1, 1.0, 10.0]},
            'lasso': {'alpha': [0.001, 0.01, 0.1, 1.0]},
            'elasticnet': {'alpha': [0.001, 0.01, 0.1, 1.0], 'l1_ratio': [0.1, 0.5, 0.7, 1.0]},
            'svr': {'C': [0.1, 1, 10], 'kernel': ['linear', 'poly', 'rbf']},
            'decision_tree': {'max_depth': [None, 10, 20, 30]},
            'random_forest': {'n_estimators': [10, 50, 100], 'max_depth': [None, 10, 20, 30]},
            'gbr': {'n_estimators': [50, 100], 'learning_rate': [0.01, 0.1, 0.2], 'max_depth': [3, 5, 7]},
            'knn': {'n_neighbors': [3, 5, 7, 10]},
            'polynomial': {'poly__degree': [2, 3, 4]},
            'bayesian': {'alpha_1': [1e-6, 1e-3, 1e-1], 'lambda_1': [1e-6, 1e-3, 1e-1]},
            'huber': {'epsilon': [1.35, 1.5, 1.75]}
        }

    results = {}

    # Начало родительского запуска
    parent_run_name = f"Model_Tuning_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}"
    with mlflow.start_run(run_name=parent_run_name) as parent_run:
        for model_name, model in models.items():
            with mlflow.start_run(run_name=model_name, nested=True):
                # Параметры для данной модели
                param_grid = param_grids.get(model_name, {})

                # Настройка модели с использованием GridSearchCV
                grid_search = GridSearchCV(estimator=model, param_grid=param_grid, cv=cv, scoring='neg_mean_squared_error')
                grid_search.fit(X, y)

                # Лучшая модель, параметры и результат
                best_model = grid_search.best_estimator_
                best_params = grid_search.best_params_
                best_rmse = np.sqrt(-grid_search.best_score_)

                # Логируем модель и параметры в MLflow
                mlflow.log_params(best_params)
                mlflow.log_metric("rmse", best_rmse)
                mlflow.sklearn.log_model(best_model, "model")

                # Сохраняем результаты в словарь
                results[model_name] = {
                    'model': best_model,
                    'params': best_params,
                    'rmse': best_rmse
                }

    return results

# Пример использования:
X = data.drop( columns="Close")
y = data["Close"]
results = tune_and_log_models(X, y)
print(results)
# Out:
# ---------------------------------------------------------------------------
# MlflowException                           Traceback (most recent call last)
# Cell In[3], line 94
#      92 X = data.drop( columns="Close")
#      93 y = data["Close"]
# ---> 94 results = tune_and_log_models(X, y)
#      95 print(results)
#
# Cell In[3], line 62, in tune_and_log_models(X, y, models, param_grids, cv)
#      60 # Начало родительского запуска
#      61 parent_run_name = f"Model_Tuning_{datetime.now().strftime('%Y-%m-%d_%H-%M-%S')}"
# ---> 62 with mlflow.start_run(run_name=parent_run_name) as parent_run:
#      63     for model_name, model in models.items():
#      64         with mlflow.start_run(run_name=model_name, nested=True):
#      65             # Параметры для данной модели
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/tracking/fluent.py:326, in start_run(run_id, experiment_id, run_name, nested, parent_run_id, tags, description, log_system_metrics)
#     318 if len(_active_run_stack) > 0 and not nested:
#     319     raise Exception(
#     320         (
#     321             "Run with UUID {} is already active. To start a new run, first end the "
#    (...)
#     324         ).format(_active_run_stack[0].info.run_id)
#     325     )
# --> 326 client = MlflowClient()
#     327 if run_id:
#     328     existing_run_id = run_id
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/tracking/client.py:134, in MlflowClient.__init__(self, tracking_uri, registry_uri)
#     132 final_tracking_uri = utils._resolve_tracking_uri(tracking_uri)
#     133 self._registry_uri = registry_utils._resolve_registry_uri(registry_uri, tracking_uri)
# --> 134 self._tracking_client = TrackingServiceClient(final_tracking_uri)
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:81, in TrackingServiceClient.__init__(self, tracking_uri)
#      76 self.tracking_uri = tracking_uri
#      77 # NB: Fetch the tracking store (`self.store`) upon client initialization to ensure that
#      78 # the tracking URI is valid and the store can be properly resolved. We define `store` as a
#      79 # property method to ensure that the client is serializable, even if the store is not
#      80 # self.store
# ---> 81 self.store
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/client.py:85, in TrackingServiceClient.store(self)
#      83 @property
#      84 def store(self):
# ---> 85     return utils._get_store(self.tracking_uri)
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:205, in _get_store(store_uri, artifact_uri)
#     204 def _get_store(store_uri=None, artifact_uri=None):
# --> 205     return _tracking_store_registry.get_store(store_uri, artifact_uri)
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/registry.py:42, in TrackingStoreRegistry.get_store(self, store_uri, artifact_uri)
#      39 from mlflow.tracking._tracking_service import utils
#      41 resolved_store_uri = utils._resolve_tracking_uri(store_uri)
# ---> 42 return self._get_store_with_resolved_uri(resolved_store_uri, artifact_uri)
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/registry.py:52, in TrackingStoreRegistry._get_store_with_resolved_uri(self, resolved_store_uri, artifact_uri)
#      46 """
#      47 Retrieve the store associated with a resolved (non-None) store URI and an artifact URI.
#      48 Caching is done on resolved URIs because the meaning of an unresolved (None) URI may change
#      49 depending on external configuration, such as environment variables
#      50 """
#      51 builder = self.get_store_builder(resolved_store_uri)
# ---> 52 return builder(store_uri=resolved_store_uri, artifact_uri=artifact_uri)
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/tracking/_tracking_service/utils.py:138, in _get_sqlalchemy_store(store_uri, artifact_uri)
#     136 if artifact_uri is None:
#     137     artifact_uri = DEFAULT_LOCAL_FILE_AND_ARTIFACT_PATH
# --> 138 return SqlAlchemyStore(store_uri, artifact_uri)
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/store/tracking/sqlalchemy_store.py:175, in SqlAlchemyStore.__init__(self, db_uri, default_artifact_root)
#     171 SessionMaker = sqlalchemy.orm.sessionmaker(bind=self.engine)
#     172 self.ManagedSessionMaker = mlflow.store.db.utils._get_managed_session_maker(
#     173     SessionMaker, self.db_type
#     174 )
# --> 175 mlflow.store.db.utils._verify_schema(self.engine)
#     177 if is_local_uri(default_artifact_root):
#     178     mkdir(local_file_uri_to_path(default_artifact_root))
#
# File ~/miniconda3/envs/tr_env/lib/python3.10/site-packages/mlflow/store/db/utils.py:119, in _verify_schema(engine)
#     117 current_rev = _get_schema_version(engine)
#     118 if current_rev != head_revision:
# --> 119     raise MlflowException(
#     120         f"Detected out-of-date database schema (found version {current_rev}, "
#     121         f"but expected {head_revision}). Take a backup of your database, then run "
#     122         "'mlflow db upgrade <database_uri>' "
#     123         "to migrate your database to the latest schema. NOTE: schema migration may "
#     124         "result in database downtime - please consult your database's documentation for "
#     125         "more detail."
#     126     )
#
# MlflowException: Detected out-of-date database schema (found version 5b0e9adcef9c, but expected 4465047574b1). Take a backup of your database, then run 'mlflow db upgrade <database_uri>' to migrate your database to the latest schema. NOTE: schema migration may result in database downtime - please consult your database's documentation for more detail.
